# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def extract(page):
    url = 'https://br.linkedin.com/jobs/search?keywords=Engenheiro%20de%20dados&location=Brasil&geoId=106057199&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum={page}'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'lxml')
    return soup

def transform(soup):
    divs = soup.find_all('div',class_='base-card relative w-full hover:no-underline focus:no-underline base-card--link base-search-card base-search-card--link job-search-card')
    for item in divs:
        title = item.find('a').text.strip()
        company = item.find('h4').text.strip()
        location = item.find('span', class_='job-search-card__location').text.strip()
        description = item.find('div',class_='show-more-less-html__markup')
        print(description)
    return

c=extract(0)
transform(c)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
def extract(page):
    url = 'https://www.vagas.com.br/vagas-de-analista-de-dados?'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'}
    r = requests.get(url, headers)
    soup = BeautifulSoup(r.content, 'lxml')
    return soup

def test(soup):
    divs = soup.find_all('li',class_='vaga odd')
    for item in divs:
        title = item.find('h2').text.strip()
        company = item.find('span', class_='emprVaga').text.strip()
        location = item.find('span', class_='vaga-local').text.strip()
        description = item.find('p')
        level_cargo = item.find('span', class_='nivelVaga').text.strip()
        job = {
            'vaga-local': title,
            'Company': company,
            'emprVaga': location,
            'p': description,
            'nivelVaga': level_cargo
        }
        joblist.append(job)
    return
joblist = []

#page = int(input(f'enter the page number you are looking:'))

for i in range(0,50,10):
    print(f'gettinf page,{i}')

    s = extract(0)
    c = test(s)

df = pd.DataFrame(joblist)
df
# Out:
# gettinf page,0
# gettinf page,10
# gettinf page,20
# gettinf page,30
# gettinf page,40
#                       vaga-local                    Company  \
# 0              Analista de Dados             Rádio Itatiaia
# 1              Analista de Dados                   Manpower
# 2              Analista de Dados             ERG Engenharia
# 3       Analista de Dados Sênior       Marfrig Global Foods
# 4           Analista de Dados/bi                  123Milhas
# ..                           ...                        ...
# 95         Analista de Operações                   SX Tools
# 96            Analista Sig Pleno  Tetra Tech América do Sul
# 97  Analista de Compliance Pleno            Prumo Logística
# 98           Analista de Pricing              Minerva Foods
# 99       Analista de Faturamento               Confidencial
#
#                emprVaga                                                  p  \
# 0          Minas Gerais  [Descrição: O , [Analista],  de , [Dados],  é ...
# ...

# %%
df = df.to_csv("teste0303.csv")
